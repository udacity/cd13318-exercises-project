# %%
import os

os.environ['OPENAI_API_KEY'] = "your key here"


print(os.environ)

# %%
from openai import OpenAI

client = OpenAI()

prompt = """How would you measure the diameter of the planet Earth using Eratosthenes method?
"""

completion = client.chat.completions.create(
  model="gpt-4",
  messages=[
    {"role": "user", "content": prompt}
  ]
)

print(completion.choices[0].message.content)
# Out:
# Eratosthenes was a Greek mathematician, geographer, and astronomer who developed a simple and effective method of measuring the Earth's diameter back in 240 B.C. Here is how his method works:
#
# 1. Choose two places that lie on the same meridian (a circle of constant longitude passing through the North and South poles). Eratosthenes chose Alexandria and Syene (modern Aswan), in Egypt.
#
# 2. Determine the distance between these two places. This can be done in various ways such as measuring the time it takes to travel from one place to the other, or using geographic methods. Eratosthenes paid a man to walk the distance and count his steps. For our case, we can simply use the well-known distance.
#
# ...

# %%
from openai import OpenAI

client = OpenAI()

prompt = """How would you measure the diameter of the planet Earth using Eratosthenes method?

Give a step by step process to achieve this.
"""

completion = client.chat.completions.create(
  model="gpt-4",
  messages=[
    {"role": "user", "content": prompt}
  ]
)

print(completion.choices[0].message.content)
# Out:
# Step 1: Choose Two Locations on the Same Meridian
#
# Eratosthenes chose the cities of Alexandria and Syene (Aswan today) that were roughly on the same meridian.
#
# Step 2: Measure the Angle of Sunlight
#
# Eratosthenes knew from travelers that on the summer solstice at local noon in the Ancient Egyptian city of Swenet (Syene) the Sun stood directly overhead. Under idealized circumstances, he could therefore use the shadow of a rod to find the angle between the vertical and the straight line to the Sun. This angle would be zero at Syene, as the Sun was directly overhead.
#
# Step 3: Compare the Angle to the Shadow Cast in Alexandria
#
# In Alexandria, the vertical rod cast a shadow at an angle. Eratosthenes measured the angle of the shadow as approximately 7.2 degrees, or about 1/50 of a full circle.
#
# Step 4: Measure the Distance Between the Two Cities
#
# Eratosthenes learned that the distance between Alexandria and Syene was approximately 800 km (500 miles).
#
# ...
